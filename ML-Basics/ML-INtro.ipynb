# %% [markdown]
# ## Types of ML models
# - regression
# - classification
# - clustering

# %% [markdown]
# # 1. Regression
# ### To predict continous linear values from the given data.
# steps:
#  1. import the required libraries
#  2. Gather all the required data
# ____________________________________________________________________________________________________
#
#  3. Define features(X) and target(Y)
#  4. splitting data into training and testing datasets
#  5. use training data to train the model
#  6. use testing data to test model performance
#  7. visualize the final model

# %%
import numpy as np ## linear algebra
import pandas as pd ## data processing, data transformation, data cleaning, data manipulation
from sklearn.linear_model import LinearRegression ## use to create a linear regression model
import matplotlib.pyplot as plt ## use to plot the data and the regression line
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
# ...

# %%
! pip install numpy pandas scikit-learn matplotlib
# Out:
# ^C
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached matplotlib-3.10.9-cp313-cp313-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
# Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
# Using cached matplotlib-3.10.9-cp313-cp313-win_amd64.whl (8.2 MB)
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# ...
#
#    ---------------------------------------- 0/3 [contourpy]
#    ---------------------------------------- 0/3 [contourpy]
#    ---------------------------------------- 0/3 [contourpy]
#    ------------- -------------------------- 1/3 [scikit-learn]
#    ------------- -------------------------- 1/3 [scikit-learn]
#    ------------- -------------------------- 1/3 [scikit-learn]
#    ------------- -------------------------- 1/3 [scikit-learn]
# ...

# %% [markdown]
# ### experimenting with random data

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.style.use('ggplot') 
import numpy as np

# %%
randomdata = np.random.RandomState(1) 
x = 10 * randomdata.rand(50) 
y = 2 * x - 5 + randomdata.rand(50)
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x[:,np.newaxis], y)

xfit = np.linspace(0, 10, 100)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit,color='green')
